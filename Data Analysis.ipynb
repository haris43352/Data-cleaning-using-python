# %%
headers=["symbol","normalizer_losses","make","Fuel_type","aspiration",
"number of doors","body style","drive_wheels","engine_location",
"wheel base","length","width","height","curb_weight","engine_type"
"number_cyline","engine_size","fuel_system","bore",
"stroke","compression_ratio","horse_power","peak","rpm","city_mpg","highway_mpg","price"]

# %%
df.shape

# %%
path="C:/Users/abdul/OneDrive/Desktop/excel/automobile.csv"
df.to_csv(path)

# %%
df.describe()
# Out:
#            symbol  wheel base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb_weight  fuel_system  horse_power    city_mpg  highway_mpg
# count   205.000000   205.000000   205.000000  205.000000   205.000000
# mean   2555.565854   126.907317    10.142537   25.219512    30.751220
# std     520.680204    41.642693     3.972040    6.542142     6.886443
# min    1488.000000    61.000000     7.000000   13.000000    16.000000
# ...

# %%
df.describe(include="all")
# Out:
#             symbol normalizer_losses    make Fuel_type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        number of doors body style drive_wheels engine_location  wheel base  \
# count              205        205          205             205  205.000000
# ...

# %%
import pandas as pd
path="C:/Users/abdul/OneDrive/Desktop/excel/automobile.csv"
df=pd.read_csv(path)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'normalizer_losses', 'make', 'Fuel_type',
#        'aspiration', 'number of doors', 'body style', 'drive_wheels',
#        'engine_location', 'wheel base', 'length', 'width', 'height',
#        'curb_weight', 'engine_typenumber_cyline', 'engine_size', 'fuel_system',
#        'bore', 'stroke', 'compression_ratio', 'horse_power', 'peak', 'rpm',
#        'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                205 non-null    int64
#  1   symbol                    205 non-null    int64
#  2   normalizer_losses         205 non-null    object
#  3   make                      205 non-null    object
#  4   Fuel_type                 205 non-null    object
#  5   aspiration                205 non-null    object
#  6   number of doors           205 non-null    object
#  7   body style                205 non-null    object
#  8   drive_wheels              205 non-null    object
#  9   engine_location           205 non-null    object
#  10  wheel base                205 non-null    float64
#  11  length                    205 non-null    float64
#  12  width                     205 non-null    float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  symbol normalizer_losses         make Fuel_type aspiration  \
# 0           0       3                 ?  alfa-romero       gas        std
# 1           1       3                 ?  alfa-romero       gas        std
# 2           2       1                 ?  alfa-romero       gas        std
# 3           3       2               164         audi       gas        std
# 4           4       2               164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  ...  fuel_system  \
# 0             two  convertible          rwd           front  ...          130
# 1             two  convertible          rwd           front  ...          130
# 2             two    hatchback          rwd           front  ...          152
# 3            four        sedan          fwd           front  ...          109
# 4            four        sedan          4wd           front  ...          136
#
# ...

# %%
import numpy as np
df.replace("?",np.nan, inplace =True)
df.head()
# Out:
#    Unnamed: 0  symbol normalizer_losses         make Fuel_type aspiration  \
# 0           0       3               NaN  alfa-romero       gas        std
# 1           1       3               NaN  alfa-romero       gas        std
# 2           2       1               NaN  alfa-romero       gas        std
# 3           3       2               164         audi       gas        std
# 4           4       2               164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  ...  fuel_system  \
# 0             two  convertible          rwd           front  ...          130
# 1             two  convertible          rwd           front  ...          130
# 2             two    hatchback          rwd           front  ...          152
# 3            four        sedan          fwd           front  ...          109
# 4            four        sedan          4wd           front  ...          136
#
# ...

# %%
df.count()
# Out:
# Unnamed: 0                  205
# symbol                      205
# normalizer_losses           164
# make                        205
# Fuel_type                   205
# aspiration                  205
# number of doors             203
# body style                  205
# drive_wheels                205
# engine_location             205
# wheel base                  205
# length                      205
# width                       205
# height                      205
# curb_weight                 205
# engine_typenumber_cyline    205
# engine_size                 205
# fuel_system                 205
# bore                        205
# stroke                      201
# compression_ratio           201
# horse_power                 205
# peak                        203
# rpm                         203
# city_mpg                    205
# highway_mpg                 205
# price                       201
# dtype: int64

# %% [markdown]
# # data wragling

# %%
# to me is ma bht sa tariqa lga skta ho 
# df.dropna 
# df.dropna(axis=0)
# mgr hum ya ni kre ga kiuka is sa hmara data kum bhi ho skta ha is vja sa hum kia krta ha ka missing values ko average 
# mean ya media sa kr skta ha or hum yha mean use kre ga

# %%
missing_data= df.isnull() # kia return kre ga jha pa null ho ga vha pa true

# %%
missing_data.head()
# Out:
#    Unnamed: 0  symbol  normalizer_losses   make  Fuel_type  aspiration  \
# 0       False   False               True  False      False       False
# 1       False   False               True  False      False       False
# 2       False   False               True  False      False       False
# 3       False   False              False  False      False       False
# 4       False   False              False  False      False       False
#
#    number of doors  body style  drive_wheels  engine_location  ...  \
# 0            False       False         False            False  ...
# 1            False       False         False            False  ...
# 2            False       False         False            False  ...
# 3            False       False         False            False  ...
# 4            False       False         False            False  ...
#
#    fuel_system   bore  stroke  compression_ratio  horse_power   peak    rpm  \
# ...

# %%
for column in missing_data:
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    205
# Name: Unnamed: 0, dtype: int64
#
# symbol
# False    205
# Name: symbol, dtype: int64
#
# normalizer_losses
# False    164
# True      41
# Name: normalizer_losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# Fuel_type
# False    205
# Name: Fuel_type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# number of doors
# False    203
# True       2
# Name: number of doors, dtype: int64
#
# body style
# False    205
# Name: body style, dtype: int64
#
# drive_wheels
# False    205
# Name: drive_wheels, dtype: int64
#
# engine_location
# False    205
# Name: engine_location, dtype: int64
#
# wheel base
# False    205
# Name: wheel base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb_weight
# False    205
# Name: curb_weight, dtype: int64
#
# engine_typenumber_cyline
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                205 non-null    int64
#  1   symbol                    205 non-null    int64
#  2   normalizer_losses         164 non-null    object
#  3   make                      205 non-null    object
#  4   Fuel_type                 205 non-null    object
#  5   aspiration                205 non-null    object
#  6   number of doors           203 non-null    object
#  7   body style                205 non-null    object
#  8   drive_wheels              205 non-null    object
#  9   engine_location           205 non-null    object
#  10  wheel base                205 non-null    float64
#  11  length                    205 non-null    float64
#  12  width                     205 non-null    float64
# ...

# %%
mean_norm_loss=df["normalizer_losses"].astype("float").mean(axis=0)
print(f"the mean of normalized losses are {mean_norm_loss}")
# Out:
# the mean of normalized losses are 122.0

# %%
df["normalizer_losses"].replace(np.nan,mean_norm_loss,inplace= True)

# %%
avg_stroke=df["stroke"].astype("float").mean(axis=0)
print("the average stroke is",avg_stroke)
# Out:
# the average stroke is 3.3297512437810957

# %%
df["stroke"].replace(np.nan,avg_stroke,inplace= True)

# %%
avg_CR=df["compression_ratio"].astype("float").mean(axis=0)
print("the avg of CR is",avg_CR)
# Out:
# the avg of CR is 3.2554228855721337

# %%
df["compression_ratio"].replace(np.nan,avg_CR,inplace = True)

# %%
avg_peak=df["peak"].astype("float").mean(axis=0)
print("the average of peak is ",avg_peak)
# Out:
# the average of peak is  104.25615763546799

# %%
df["peak"].replace(np.nan,avg_peak,inplace= True)

# %%
avg_rpm=df["rpm"].astype("float").mean(axis=0)

# %%
df["rpm"].replace(np.nan,avg_rpm,inplace= True)

# %%
avg_price=df["price"].astype("float").mean(axis=0)
print("the average of peak is ",avg_price)
# Out:
# the average of peak is  13207.129353233831

# %%
df["price"].replace(np.nan,avg_price,inplace= True)

# %% [markdown]
# # covertig data types

# %%
df[["normalizer_losses"]] = df[["normalizer_losses"]].astype("int")

# %%
df[["price"]]=df[["price"]].astype("float")

# %%
df[["stroke"]]=df[["stroke"]].astype("float")

# %%
df[["peak","rpm"]]=df[["peak","rpm"]].astype("int")

# %%
df.head()
# Out:
#    Unnamed: 0  symbol  normalizer_losses         make Fuel_type aspiration  \
# 0           0       3                122  alfa-romero       gas        std
# 1           1       3                122  alfa-romero       gas        std
# 2           2       1                122  alfa-romero       gas        std
# 3           3       2                164         audi       gas        std
# 4           4       2                164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  ...  fuel_system  \
# 0             two  convertible          rwd           front  ...          130
# 1             two  convertible          rwd           front  ...          130
# 2             two    hatchback          rwd           front  ...          152
# 3            four        sedan          fwd           front  ...          109
# 4            four        sedan          4wd           front  ...          136
#
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  symbol  normalizer_losses   make Fuel_type aspiration  \
# 200         200      -1                 95  volvo       gas        std
# 201         201      -1                 95  volvo       gas      turbo
# 202         202      -1                 95  volvo       gas        std
# 203         203      -1                 95  volvo    diesel      turbo
# 204         204      -1                 95  volvo       gas      turbo
#
#     number of doors body style drive_wheels engine_location  ...  fuel_system  \
# 200            four      sedan          rwd           front  ...          141
# 201            four      sedan          rwd           front  ...          141
# 202            four      sedan          rwd           front  ...          173
# 203            four      sedan          rwd           front  ...          145
# 204            four      sedan          rwd           front  ...          141
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# symbol                        int64
# normalizer_losses             int32
# make                         object
# Fuel_type                    object
# aspiration                   object
# number of doors              object
# body style                   object
# drive_wheels                 object
# engine_location              object
# wheel base                  float64
# length                      float64
# width                       float64
# height                      float64
# curb_weight                   int64
# engine_typenumber_cyline     object
# engine_size                  object
# fuel_system                   int64
# bore                         object
# stroke                      float64
# compression_ratio            object
# horse_power                 float64
# peak                          int32
# rpm                           int32
# city_mpg                      int64
# highway_mpg                   int64
# ...

# %% [markdown]
# # now the data has been cleaned and formated

# %%
df["city_mpg"].mean()
# Out:
# 25.21951219512195

# %% [markdown]
# # Data standarization

# %%
# it make data to understand more easily

df["city_L/100Km"]=235/df["city_mpg"]

# %%
df["highway_L/100Km"]=235/df["highway_mpg"]

# %%
df.head()
# Out:
#    Unnamed: 0  symbol  normalizer_losses         make Fuel_type aspiration  \
# 0           0       3                122  alfa-romero       gas        std
# 1           1       3                122  alfa-romero       gas        std
# 2           2       1                122  alfa-romero       gas        std
# 3           3       2                164         audi       gas        std
# 4           4       2                164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  ...  stroke  \
# 0             two  convertible          rwd           front  ...    3.47
# 1             two  convertible          rwd           front  ...    3.47
# 2             two    hatchback          rwd           front  ...    2.68
# 3            four        sedan          fwd           front  ...    3.19
# 4            four        sedan          4wd           front  ...    3.19
#
# ...

# %% [markdown]
# # Data Normalization

# %%
""""
If a feature in your data has values that cover a very large range
(e.g., some values in the thousands and others in the single digits), 
it's a good idea to normalize that feature. Normalization will bring all the values to a similar scale, 
making it easier for your analysis or models to work with them effectively
it could be three type
1 simple feature
2 min max
3 z score"""
# Out:
# '"\nIf a feature in your data has values that cover a very large range\n(e.g., some values in the thousands and others in the single digits), \nit\'s a good idea to normalize that feature. Normalization will bring all the values to a similar scale, \nmaking it easier for your analysis or models to work with them effectively\nit could be three typle\n1 simple feature\n2 min max\n3 z score'

# %%
df['length']=df['length']/df['length'].max()

# %%
df['height']=df['height']/df['height'].max()

# %%
df['width']=df['width']/df['width'].max()

# %%
df.head()
# Out:
#    Unnamed: 0  symbol  normalizer_losses         make Fuel_type aspiration  \
# 0           0       3                122  alfa-romero       gas        std
# 1           1       3                122  alfa-romero       gas        std
# 2           2       1                122  alfa-romero       gas        std
# 3           3       2                164         audi       gas        std
# 4           4       2                164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  ...  stroke  \
# 0             two  convertible          rwd           front  ...    3.47
# 1             two  convertible          rwd           front  ...    3.47
# 2             two    hatchback          rwd           front  ...    2.68
# 3            four        sedan          fwd           front  ...    3.19
# 4            four        sedan          4wd           front  ...    3.19
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'normalizer_losses', 'make', 'Fuel_type',
#        'aspiration', 'number of doors', 'body style', 'drive_wheels',
#        'engine_location', 'wheel base', 'length', 'width', 'height',
#        'curb_weight', 'engine_typenumber_cyline', 'engine_size', 'fuel_system',
#        'bore', 'stroke', 'compression_ratio', 'horse_power', 'peak', 'rpm',
#        'city_mpg', 'highway_mpg', 'price', 'city_L/100Km', 'highway_L/100Km'],
#       dtype='object')

# %%
df['peak'].dtypes
# Out:
# dtype('int32')

# %%
df.describe()
# Out:
#        Unnamed: 0      symbol  normalizer_losses  wheel base      length  \
# count  205.000000  205.000000         205.000000  205.000000  205.000000
# mean   102.000000    0.834146         122.000000   98.756585    0.836373
# std     59.322565    1.245307          31.681008    6.021776    0.059285
# min      0.000000   -2.000000          65.000000   86.600000    0.678039
# 25%     51.000000    0.000000         101.000000   94.500000    0.799135
# 50%    102.000000    1.000000         122.000000   97.000000    0.832292
# 75%    153.000000    2.000000         137.000000  102.400000    0.879865
# max    204.000000    3.000000         256.000000  120.900000    1.000000
#
#             width      height  curb_weight  fuel_system      stroke  \
# count  205.000000  205.000000   205.000000   205.000000  205.000000
# mean     0.911588    0.898409  2555.565854   126.907317    3.329751
# std      0.029671    0.040862   520.680204    41.642693    0.270844
# ...

# %%
df.corr()
# Out:
#                    Unnamed: 0    symbol  normalizer_losses  wheel base  \
# Unnamed: 0           1.000000 -0.151621          -0.238306    0.129729
# symbol              -0.151621  1.000000           0.465190   -0.531954
# normalizer_losses   -0.238306  0.465190           1.000000   -0.056518
# wheel base           0.129729 -0.531954          -0.056518    1.000000
# length               0.170636 -0.357612           0.019209    0.874587
# width                0.052387 -0.232919           0.084195    0.795144
# height               0.255960 -0.541038          -0.370706    0.589435
# curb_weight          0.071962 -0.227691           0.097785    0.776386
# fuel_system         -0.033930 -0.105790           0.110997    0.569329
# stroke               0.260077 -0.130083          -0.029266    0.488760
# horse_power          0.150276 -0.178515          -0.114525    0.249786
# peak                -0.013346  0.071380           0.203434    0.351985
# ...

# %%
# Find the correlation between the following columns: bore, stroke, compression-ratio, 
#and horsepower.
df[['bore','stroke','compression_ratio','horse_power']].corr()
# Out:
#                stroke  horse_power
# stroke       1.000000     0.005201
# horse_power  0.005201     1.000000

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'normalizer_losses', 'make', 'Fuel_type',
#        'aspiration', 'number of doors', 'body style', 'drive_wheels',
#        'engine_location', 'wheel base', 'length', 'width', 'height',
#        'curb_weight', 'engine_typenumber_cyline', 'engine_size', 'fuel_system',
#        'bore', 'stroke', 'compression_ratio', 'horse_power', 'peak', 'rpm',
#        'city_mpg', 'highway_mpg', 'price', 'city_L/100Km', 'highway_L/100Km'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.bar(df['engine_size'],df['price'])
# Out:
# <BarContainer object of 205 artists>

# %%
df['peak'].rename('engine_size')
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: engine_size, Length: 205, dtype: int32

# %%
df['rpm'].rename('peak')
# Out:
# 0      5000
# 1      5000
# 2      5000
# 3      5500
# 4      5500
#        ...
# 200    5400
# 201    5300
# 202    5500
# 203    4800
# 204    5400
# Name: peak, Length: 205, dtype: int32

# %%
plt.scatter(df['engine_size'],df['price'],marker="x",c="r")

# %%
sns.regplot(x=df['rpm'],y=df['price'])
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
sns.regplot(x=df['peak'],y=df['price'])
plt.ylim(0,)
# Out:
# (0.0, 50295.604933613206)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'normalizer_losses', 'make', 'Fuel_type',
#        'aspiration', 'number of doors', 'body style', 'drive_wheels',
#        'engine_location', 'wheel base', 'length', 'width', 'height',
#        'curb_weight', 'engine_typenumber_cyline', 'engine_size', 'fuel_system',
#        'bore', 'stroke', 'compression_ratio', 'horse_power', 'peak', 'rpm',
#        'city_mpg', 'highway_mpg', 'price', 'city_L/100Km', 'highway_L/100Km'],
#       dtype='object')

# %%
sns.regplot(x='stroke',y='price',data=df)
plt.ylim(0,)
# Out:
# (0.0, 47768.036718779455)

# %%
sns.boxplot(x="body style", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='body style', ylabel='price'>

# %%
sns.boxplot(x="engine_location", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='engine_location', ylabel='price'>

# %%
sns.boxplot(x="drive_wheels", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='drive_wheels', ylabel='price'>

# %% [markdown]
# ### Value counts

# %%
df['drive_wheels'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drive_wheels, dtype: int64

# %%
df['drive_wheels'].value_counts().to_frame()
# Out:
#      drive_wheels
# fwd           120
# rwd            76
# 4wd             9

# %%
drive_wheels_counts = df['drive_wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive_wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           120
# rwd            76
# 4wd             9

# %%
drive_wheels_counts.index.name="drive_wheels"

# %%
drive_wheels_counts
# Out:
#               value_counts
# drive_wheels
# fwd                    120
# rwd                     76
# 4wd                      9

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symbol', 'normalizer_losses', 'make', 'Fuel_type',
#        'aspiration', 'number of doors', 'body style', 'drive_wheels',
#        'engine_location', 'wheel base', 'length', 'width', 'height',
#        'curb_weight', 'engine_typenumber_cyline', 'engine_size', 'fuel_system',
#        'bore', 'stroke', 'compression_ratio', 'horse_power', 'peak', 'rpm',
#        'city_mpg', 'highway_mpg', 'price', 'city_L/100Km', 'highway_L/100Km'],
#       dtype='object')

# %%
engine_loc_counts=df['engine_location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine_location':'value_counts'},inplace=True)
engine_loc_counts
# Out:
#        value_counts
# front           202
# rear              3

# %%
engine_loc_counts.index.name="engine_location"

# %%
engine_loc_counts.head()
# is also a not a good predictor of price becace 97 of the car has engine on front 
# on 3 percent has rear
# Out:
#                  value_counts
# engine_location
# front                     202
# rear                        3

# %% [markdown]
# # Grouping

# %%
# grouping can be done on categorical variable 
# from that  we can determine which thing has the highest value and has the most impact
# it can be done by
grouping=df[['drive_wheels','body style','price']]

# %%
group_test=grouping.groupby(['drive_wheels','body style'],as_index=False).mean()

# %%
group_test=group_test.pivot(index='drive_wheels',columns='body style')

# %%
group_test
# Out:
#                    price                                            \
# body style   convertible       hardtop     hatchback         sedan
# drive_wheels
# 4wd                  NaN           NaN  10405.064677  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9930.934363
# rwd              23949.6  24202.714286  14278.269966  21711.833333
#
#
# body style           wagon
# drive_wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
group_test.fillna(0)
# Out:
#                    price                                            \
# body style   convertible       hardtop     hatchback         sedan
# drive_wheels
# 4wd                  0.0      0.000000  10405.064677  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9930.934363
# rwd              23949.6  24202.714286  14278.269966  21711.833333
#
#
# body style           wagon
# drive_wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
other_group=df[['body style','price']]

# %%
b=other_group.groupby(['body style'],as_index=False).mean()

# %%
b
# Out:
#     body style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback  10050.289410
# 3        sedan  14433.658945
# 4        wagon  12371.960000

# %%
plt.pcolor(group_test,cmap="RdBu")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(group_test, cmap='RdBu')

#label names
row_labels = group_test.columns.levels[1]
col_labels = group_test.index

#move ticks and labels to the center
ax.set_xticks(np.arange(group_test.shape[1]) + 0.7, minor=False)
ax.set_yticks(np.arange(group_test.shape[0]) + 0.7, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
import scipy

# %%
from scipy import stats

# %%
df.corr()
# Out:
#                    Unnamed: 0    symbol  normalizer_losses  wheel base  \
# Unnamed: 0           1.000000 -0.151621          -0.238306    0.129729
# symbol              -0.151621  1.000000           0.465190   -0.531954
# normalizer_losses   -0.238306  0.465190           1.000000   -0.056518
# wheel base           0.129729 -0.531954          -0.056518    1.000000
# length               0.170636 -0.357612           0.019209    0.874587
# width                0.052387 -0.232919           0.084195    0.795144
# height               0.255960 -0.541038          -0.370706    0.589435
# curb_weight          0.071962 -0.227691           0.097785    0.776386
# fuel_system         -0.033930 -0.105790           0.110997    0.569329
# stroke               0.260077 -0.130083          -0.029266    0.488760
# horse_power          0.150276 -0.178515          -0.114525    0.249786
# peak                -0.013346  0.071380           0.203434    0.351985
# ...

# %%
pc_pv=stats.pearsonr(x=df['wheel base'],y=df['price'])

# %%
pc_pv
# Out:
# PearsonRResult(statistic=0.5831681499789549, pvalue=4.527625545686636e-20)

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5831681499789549  with a P-value of P = 4.527625545686636e-20

# %%
pearson_coef, p_value = stats.pearsonr(df['horse_power'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.07099036277901556  with a P-value of P =  0.31178249194905244

# %%
sns.regplot(df.horse_power,df.price)
# Out:
# C:\Users\abdul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horse_power', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6829862954386219  with a P-value of P =  1.6498873291218535e-29

# %%
grouped_test2=df[['drive_wheels', 'price']].groupby(['drive_wheels'])
grouped_test2.head(2)
# Out:
#   drive_wheels         price
# 0          rwd  13495.000000
# 1          rwd  16500.000000
# 3          fwd  13950.000000
# 4          4wd  17450.000000
# 5          fwd  15250.000000
# 9          4wd  13207.129353

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# 4      17450.000000
# 9      13207.129353
# 140     7603.000000
# 144     9233.000000
# 145    11259.000000
# 148     8013.000000
# 149    11694.000000
# 154     7898.000000
# 155     8778.000000
# Name: price, dtype: float64

# %%
# ANOVA
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.5036668266912 , P = 3.5392707916047903e-23

# %%
'''This is a great result with a large F-test score showing a strong correlation and a P-value of almost 0 
implying almost certain statistical significance. 
But does this mean all three tested groups are all this highly correlated?'''

# Let's examine them separately.
# Out:
# 'This is a great result with a large F-test score showing a strong correlation and a P-value of almost 0 \nimplying almost certain statistical significance. \nBut does this mean all three tested groups are all this highly correlated?'

# %% [markdown]
# # fwd_rwd

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 129.41115759339715 , P = 2.6524240289951807e-23

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 8.879065438652509 , P = 0.00378273257813761

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('fwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 1.1847736755700735 , P = 0.27844756008434524

# %% [markdown]
# ## Conclusion

# %% [markdown]
# # We now have a better idea of what our data looks like and which variables are important to take into account
# # when predicting the car price.
# # We have narrowed it down to the following variables

# %% [markdown]
# # Model dvolpment

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
lm
# Out:
# LinearRegression()

# %%
x=df[['highway_mpg']]
y=df['price']

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
yhat=lm.predict(x)
yhat[0:5]
# Out:
# array([16166.94140528, 16166.94140528, 16955.96802513, 13799.86154571,
#        20112.07450456])

# %%
lm.coef_
# Out:
# array([-789.02661986])

# %%
lm.intercept_
# Out:
# 37470.66014138312

# %%
lm1=LinearRegression()
lm1
# Out:
# LinearRegression()

# %%
x=df[['peak']]
y=df['price']
lm1.fit(x,y)
# Out:
# LinearRegression()

# %%
lm1.coef_
# Out:
# array([150.91647306])

# %%
lm.intercept_
# Out:
# 37470.66014138312

# %%
yhat=-2526.465+150.916*df['peak']

# %%
yhat[0:5]
# Out:
# 0    14225.211
# 1    14225.211
# 2    20714.599
# 3    12866.967
# 4    14828.875
# Name: peak, dtype: float64

# %% [markdown]
# # Multiple linear regression

# %%
# Create and train a Multiple Linear Regression model "lm2" where the response variable is "price", 
# and the predictor variable is "normalized-losses" and "highway-mpg".
lm2=LinearRegression()
lm2
# Out:
# LinearRegression()

# %%
x_multiple=df[['horse_power','curb_weight','highway_mpg']]
y=df['price']
# df.columns
# df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9400\749940580.py in <module>
# ----> 1 x_multiple=df[['horse_power','curb_weight','highway_mpg']]
#       2 y=df['price']
#       3 # df.columns
#       4 # df.columns
#
# NameError: name 'df' is not defined

# %%
lm2.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9400\2769125342.py in <module>
# ----> 1 lm2.fit(x,y)
#
# NameError: name 'lm2' is not defined

# %%
lm2.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9400\849216218.py in <module>
# ----> 1 lm2.coef_
#
# NameError: name 'lm2' is not defined

# %%
lm2.intercept_
# Out:
# -2526.4650966888203

# %%
yhat=lm2.predict(x)
yhat[0:5]
# Out:
# array([14225.26341295, 14225.26341295, 20714.67175452, 12867.01515541,
#        14828.92930519])

# %% [markdown]
# # model evolution using visualization

# %%
import seaborn as sns

# %%
'''Regression Plot

When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using regression plots.
This plot will show a combination of a scattered data points (a scatterplot)
, as well as the fitted linear regression line going through the data.
This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation,
as well as the direction (positive or negative correlation).'''
# Out:
# 'Regression Plot\n\nWhen it comes to simple linear regression, an excellent way to visualize the fit of our model is by using regression plots.\nThis plot will show a combination of a scattered data points (a scatterplot)\n, as well as the fitted linear regression line going through the data.\nThis will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation,\nas well as the direction (positive or negative correlation).'

# %%
width=6
length=5
plt.figure(figsize=(width,length))
sns.regplot(x=df.highway_mpg,y=df.price)
# Out:
# <AxesSubplot:xlabel='highway_mpg', ylabel='price'>

# %%
'''
We can see from this plot that price is negatively correlated to highway-mpg since the regression slope is negative.

One thing to keep in mind when looking at a regression plot is to pay attention to
how scattered the data points are around the regression line.
This will give you a good indication of the variance of the data and whether a linear model would be the best fit or not. 
If the data is too far off from the line, this linear model might not be the best model for this data.
Let's compare this plot to the regression plot of "peak-rpm".'''
# Out:
# '\nWe can see from this plot that price is negatively correlated to highway-mpg since the regression slope is negative.\n\nOne thing to keep in mind when looking at a regression plot is to pay attention to\nhow scattered the data points are around the regression line.\nThis will give you a good indication of the variance of the data and whether a linear model would be the best fit or not. \nIf the data is too far off from the line, this linear model might not be the best model for this data.\nLet\'s compare this plot to the regression plot of "peak-rpm".'

# %%
plt.figure(figsize=(length,width))
sns.regplot(x=df.rpm,y=df.price)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df[["rpm","highway_mpg","price"]].corr()
# Out:
#                   rpm  highway_mpg     price
# rpm          1.000000    -0.054257 -0.100851
# highway_mpg -0.054257     1.000000 -0.690526
# price       -0.100851    -0.690526  1.000000

# %%
'''
here we conclude that highway-mag has strongly
correlated then rpm'''
# Out:
# '\nhere we conclude that highway-mag has strongly\ncorrelated then rpm'

# %% [markdown]
# # Residual Plot
# A good way to visualize the variance of the data is to use a residual plot.
#
# What is a residual?
#
# The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.
#
# So what is a residual plot?
#
# A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.
#
# What do we pay attention to when looking at a residual plot?
#
# We look at the spread of the residuals:
#
# If the points in a residual plot are randomly spread out around the x-axis, then a linear model is appropriate for the data.
#
# Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.

# %%
plt.figure(figsize=(length,width))
sns.residplot(x=df.highway_mpg,y=df.price)
plt.show()

# %% [markdown]
# What is this plot telling us?
#
# We can see from this residual plot that the residuals are not randomly spread around the x-axis, leading us to believe that maybe a non-linear model is more appropriate for this data.

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# # polynomial regression model

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55,100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')
    plt.show()
    plt.close()

# %%
x=df.highway_mpg
y=df.price
f1=np.polyfit(x,y,3)
p1=np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y,'Highway_mpg')
# Out:
#         3         2
# -1.641 x + 213.4 x - 9226 x + 1.402e+05

# %% [markdown]
# # pipeline
#
# pipeline is a series of steps
# involve
# 1 First transform the data
# transforming has two steps which is standard scale,feature
# prdiction involve 1 step which is to predict

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import PolynomialFeatures
# feature scaling

# %%
pr= PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
a=pr.fit_transform(x_multiple)

# %%
a.shape
# Out:
# (205, 10)

# %%
x_multiple.shape
# Out:
# (205, 3)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

# %%
input=[('scale',StandardScaler()),('polynomial',PolynomialFeatures(include_bias=False)),('model',LinearRegression())]

# %%
pipe=Pipeline(input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z=x_multiple.astype('float')
pipe.fit(Z,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9400\2744563017.py in <module>
# ----> 1 Z=x_multiple.astype('float')
#       2 pipe.fit(Z,y)
#
# NameError: name 'x_multiple' is not defined

# %%
yhat=pipe.predict(Z)
yhat[0:3]
# Out:
# array([13522.12672344, 13522.12672344, 16588.00459008])

# %%
input=[('scale',StandardScaler()),('model',LinearRegression())]

# %%
pipe=Pipeline(input)

# %%
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', LinearRegression())])

# %%
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', LinearRegression())])

# %%
yhat=pipe.predict(Z)
yhat[0:4]
# Out:
# array([13481.67752047, 13481.67752047, 16756.69943106, 10736.21898527])

# %% [markdown]
# # 4. Measures for In-Sample Evaluation

# %% [markdown]
# When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.
#
# Two very important measures that are often used in Statistics to determine the accuracy of a model are:
#
# R^2 / R-squared
# Mean Squared Error (MSE)
# R-squared
#
# R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.
#
# The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.
#
# Mean Squared Error (MSE)
#
# The Mean Squared Error measures the average of the squares of errors. That is, the difference between actual value (y) and the estimated value (ŷ).

# %% [markdown]
# # first model
# # linear regression

# %%
x=df[['highway_mpg']]
y=df['price']
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
print("the R square error is", lm.score(x,y))
# Out:
# the R square error is 0.47682578947968457

# %% [markdown]
# We can say that ~4.659% of the variation of the price is explained by this simple linear model, which we have built using the highway_mpg data.

# %% [markdown]
# # MSE

# %%
yhat=lm.predict(x)
print("the first three predicted value is",yhat[0:3])
# Out:
# the first three predicted value is [16166.94140528 16166.94140528 16955.96802513]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(df.price,yhat)
print("the mean squared error is",mse)
# Out:
# the mean squared error is 32235628.28938213

# %% [markdown]
#    # model2 : multiple linear regression

# %%
lm2.fit(x_multiple,y)
lm2.coef_
# a=lm2.predict(x_multiple)
# Out:
# array([-52.82408719,  11.6163376 , -80.52907177])

# %%
print("the R squre is",lm2.score(x_multiple,y))
# Out:
# the R squre is 0.6777065669373254

# %% [markdown]
# the 72.315 is variation of the price is explained by multiple linear regression

# %%
yhat_m=lm2.predict(x_multiple)
print("the first three predicted value is",yhat[0:3])
# Out:
# the first three predicted value is [16166.94140528 16166.94140528 16955.96802513]

# %%
mse=mean_squared_error(y,yhat_m)

# %%
print("the mean square error is",mse)
# Out:
# the mean square error is 19858263.46062562

# %% [markdown]
# # model evoluation and refinement

# %%
df.head()
# Out:
#    Unnamed: 0  symbol  normalizer_losses         make Fuel_type aspiration  \
# 0           0       3                122  alfa-romero       gas        std
# 1           1       3                122  alfa-romero       gas        std
# 2           2       1                122  alfa-romero       gas        std
# 3           3       2                164         audi       gas        std
# 4           4       2                164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  ...  stroke  \
# 0             two  convertible          rwd           front  ...    3.47
# 1             two  convertible          rwd           front  ...    3.47
# 2             two    hatchback          rwd           front  ...    2.68
# 3            four        sedan          fwd           front  ...    3.19
# 4            four        sedan          4wd           front  ...    3.19
#
# ...

# %%
del df['symbol']

# %%
df.head()
# Out:
#    Unnamed: 0  normalizer_losses         make Fuel_type aspiration  \
# 0           0                122  alfa-romero       gas        std
# 1           1                122  alfa-romero       gas        std
# 2           2                122  alfa-romero       gas        std
# 3           3                164         audi       gas        std
# 4           4                164         audi       gas        std
#
#   number of doors   body style drive_wheels engine_location  wheel base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    stroke  compression_ratio  horse_power  peak   rpm city_mpg  highway_mpg  \
# ...

# %% [markdown]
# # Functiions for plotting

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %%
Y_data=df.price

# %%
x_data=df.drop(['price'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_data,Y_data,test_size=0.40,random_state=1)

# %%
print("the number of training sample is",x_train.shape)
print("the number of test sample is",x_test.shape)
# Out:
# the number of training sample is (123, 27)
# the number of test sample is (82, 27)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train[['horse_power']],y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train[['horse_power']],y_train)
# Out:
# 0.006401369036096005

# %%
lr.score(x_test[['horse_power']],y_test)
# Out:
# 0.0013417298243596498

# %% [markdown]
# # cross_validation_score

# %% [markdown]
# Sometimes you do not have sufficient testing data;
# as a result, you may want to perform cross-validation.
# Let's go over several methods that you can use for cross-validation.

# %%
from sklearn.model_selection import cross_val_score
rcross=cross_val_score(lr,x_data[['horse_power']],Y_data,cv=4)
rcross
# Out:
# array([-0.03280708, -0.02265076,  0.01229328, -0.50423032])

# %%
print("the mean of cross-validation is",rcross.mean(),"the standard deviation is",rcross.std())
# Out:
# the mean of cross-validation is -0.13684872010498245 the standard deviation is 0.21276654458049046

# %% [markdown]
# You can also use the function 'cross_val_predict' to predict the output. The function splits up the data into the specified number of folds, with one fold for testing and the other folds are used for training. First, import the function:

# %%
from sklearn.model_selection import cross_val_predict

# %%
yhat=cross_val_predict(lr,x_data[['horse_power']],Y_data,cv=3)

# %%
yhat[0:4]
# Out:
# array([12767.12517228, 12767.12517228, 12767.12517228, 12857.6243823 ])

# %% [markdown]
# # Part 2: Overfitting, Underfitting and Model Selection
# It turns out that the test data, sometimes referred to as the "out of sample data", is a much better measure of how well your model performs in the real world. One reason for this is overfitting.
#
# Let's go over some examples. It turns out these differences are more apparent in Multiple Linear Regression and Polynomial Regression so we will explore overfitting in that context.

# %%
lr=LinearRegression()
lr.fit(x_train[['horse_power','curb_weight','highway_mpg','peak']],y_train)
# Out:
# LinearRegression()

# %%
yhat_train=lr.predict(x_train[['horse_power','curb_weight','highway_mpg','peak']])

# %%
yhat_train[0:4]
# Out:
# array([ 5220.62696599, 14754.74679178, 11356.90782094, 15309.58382297])

# %%
yhat_test=lr.predict(x_test[['horse_power','curb_weight','highway_mpg','peak']])
yhat_test[0:4]
# Out:
# array([5709.62013988, 6127.40566297, 5378.77730447, 4410.41515703])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %% [markdown]
# Figure 1: Plot of predicted values using the training data compared to the actual values of the training data.
#
# So far, the model seems to be doing well in learning from the training dataset. But what happens when the model encounters new data from the testing dataset? When the model generates new values from the test data, we see the distribution of the predicted values is much different from the actual target values.

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_test, yhat_test, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %% [markdown]
# Figure 2: Plot of predicted value using the test data compared to the actual values of the test data.
#
# Comparing Figure 1 and Figure 2, it is evident that the distribution of the test data in Figure 1 is much better at fitting the data. This difference in Figure 2 is apparent in the range of 5000 to 15,000. This is where the shape of the distribution is extremely different. Let's see if polynomial regression also exhibits a drop in the prediction accuracy when analysing the test dataset.

# %% [markdown]
# # Overfitting
# Overfitting occurs when the model fits the noise, but not the underlying process. Therefore, when testing your model using the test set, your model does not perform as well since it is modelling noise, not the underlying process that generated the relationship. Let's create a degree 5 polynomial model.

# %%
from sklearn.preprocessing import PolynomialFeatures
x_train2,x_test2,y_train2,y_test2=train_test_split(x_data,Y_data,test_size=0.45,random_state=1)
pr=PolynomialFeatures(degree=5)

# %%
x_train_pr=pr.fit_transform(x_train2[['horse_power']])
x_test_pr=pr.fit_transform(x_test2[['horse_power']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %%
poly=LinearRegression()
poly
# Out:
# LinearRegression()

# %%
poly.fit(x_train_pr,y_train2)
# Out:
# LinearRegression()

# %%
yhat=poly.predict(x_test_pr)

# %%
yhat[0:4]
# Out:
# array([11808.83177191, 11808.83177191, 12366.87934626, 11788.21219117])

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test2[0:4].values)
# Out:
# Predicted values: [11808.83177191 11808.83177191 12366.87934626 11788.21219117]
# True values: [ 6669.          7999.          6338.         13207.12935323]

# %% [markdown]
# We will use the function "PollyPlot" that we defined at the beginning of the lab to display the training data, testing data, and the predicted function.

# %%
PollyPlot(x_train2['horse_power'], x_test2['horse_power'], y_train2, y_test2, poly,pr)

# %%
poly.score(x_train_pr,y_train2)
# Out:
# 0.10426698910042409

# %%
poly.score(x_test_pr,y_test2)
# Out:
# 0.06790343588427994

# %% [markdown]
# We see the R^2 for the training data is 0.5567 while the R^2 on the test data was -29.87. The lower the R^2, the worse the model. A negative R^2 is a sign of overfitting.
# but in my case model performing in polynomial regression

# %% [markdown]
# Let's see how the R^2 changes on the test data for different order polynomials and then plot the results

# %%
Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['horse_power']])
    
    x_test_pr = pr.fit_transform(x_test[['horse_power']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %% [markdown]
# We see the R^2 gradually increases until an order three polynomial is used. Then, the R^2 dramatically decreases at an order four polynomial.
#
#
#
#
#
#
#
# The following function will be used in the next section. Please run the cell below.

# %%
def f(order, test_data):
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_data, random_state=0)
    pr = PolynomialFeatures(degree=order)
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    x_test_pr = pr.fit_transform(x_test[['horsepower']])
    poly = LinearRegression()
    poly.fit(x_train_pr,y_train)
    PollyPlot(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly,pr)

# %%
# The following interface allows you to experiment with different polynomial orders and different amounts of data.
# interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9884\1977831462.py in <module>
#       1 # The following interface allows you to experiment with different polynomial orders and different amounts of data.
#       2
# ----> 3 interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
#
# NameError: name 'interact' is not defined

# %%
interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9884\3810692821.py in <module>
# ----> 1 interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
#
# NameError: name 'interact' is not defined

# %% [markdown]
# # Part 3: Ridge Regression
# In this section, we will review Ridge Regression and see how the parameter alpha changes the model. Just a note, here our test data will be used as validation data.
#
#
#
#
#
#
#
# Let's perform a degree two polynomial transformation on our data.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)

# %%
x_train_pr1=pr.fit_transform(x_train[['horse_power','curb_weight','peak','highway_mpg']])

# %%
x_test_pr1=pr.fit_transform(x_test[['horse_power','curb_weight','peak','highway_mpg']])

# %%
from sklearn.linear_model import Ridge

# %%
lr=Ridge(alpha=1)

# %%
lr.fit(x_train_pr1,y_train)
# Out:
# Ridge(alpha=1)

# %%
yhat=lr.predict(x_test_pr1)
yhat[0:3]
# Out:
# array([6897.6494186 , 6841.62722952, 5656.20049333])

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [6897.6494186  6841.62722952 5656.20049333 8346.32522218]
# test set : [ 6669.          7999.          6338.         13207.12935323]

# %% [markdown]
# We select the value of alpha that minimizes the test error. To do so, we can use a for loop. We have also created a progress bar to see how many iterations we have completed so far.

# %%
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr1, y_train)
    test_score, train_score = RigeModel.score(x_test_pr1, y_test), RigeModel.score(x_train_pr1, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|████████████████████████████████████████| 1000/1000 [00:08<00:00, 120.66it/s, Test Score=0.758, Train Score=0.782]

# %%
# We can plot out the value of R^2 for different alphas:

width = 12
height = 10
plt.figure(figsize=(width, height))
plt.plot(Alpha,Rsqu_test, label='validation data  ')
plt.plot(Alpha,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# # Figure 4:
# The blue line represents the R^2 of the validation data, and the red line represents the R^2 of the training data. The x-axis represents the different values of Alpha.
#
# Here the model is built and tested on the same data, so the training and test data are the same.
#
# The red line in Figure 4 represents the R^2 of the training data. As alpha increases the R^2 decreases. Therefore, as alpha increases, the model performs worse on the training data
#
# The blue line represents the R^2 on the validation data. As the value for alpha increases, the R^2 increases and converges at a point.

# %% [markdown]
# # Part 4: Grid Search
# The term alpha is a hyperparameter. Sklearn has the class GridSearchCV to make the process of finding the best hyperparameter simpler.
#
# Let's import GridSearchCV from the module model_selection.

# %%
from sklearn.model_selection import GridSearchCV

# %%
# We create a dictionary of parameter values:

# parameters1=
parameters1= [{'alpha':[0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
# Create a Ridge regression object:

RR=Ridge()
RR
# Out:
# Ridge()

# %%
# Create a ridge grid search object:

Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
Grid1.fit(x_data[['horse_power', 'curb_weight', 'peak', 'highway_mpg']],Y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %%
# The object finds the best parameter values on the validation data. We can obtain the estimator with the best parameters and assign it to the variable BestRR as follows:

BestRR=Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=1000)

# %%
BestRR.score(x_test[['horse_power', 'curb_weight', 'peak', 'highway_mpg']], y_test)
# Out:
# 0.7785141261338582

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:66
#      63 from matplotlib import _docstring
#      64 from matplotlib.backend_bases import (
#      65     FigureCanvasBase, FigureManagerBase, MouseButton)
# ---> 66 from matplotlib.figure import Figure, FigureBase, figaspect
#      67 from matplotlib.gridspec import GridSpec, SubplotSpec
#      68 from matplotlib import rcsetup, rcParamsDefault, rcParamsOrig
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:51
#      48 import matplotlib.image as mimage
#      50 from matplotlib.axes import Axes
# ---> 51 from matplotlib.gridspec import GridSpec, SubplotParams
#      52 from matplotlib.layout_engine import (
#      53     ConstrainedLayoutEngine, TightLayoutEngine, LayoutEngine,
# ...
